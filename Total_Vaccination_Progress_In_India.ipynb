# %% [markdown]
# <a href="https://colab.research.google.com/github/Annabel-Anjala-David/Data-Analysis-on-Indian-Vaccination-Rate/blob/main/Total_Vaccination_Progress_In_India.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
from pandas_profiling import ProfileReport
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from fbprophet import Prophet
from datetime import datetime, date
from folium import plugins
plt.rcParams['figure.figsize']=10,12
from fbprophet import Prophet

# %%
data = pd.read_csv("/content/Preprocessed Vacc Data.csv")
data.head(5)
# Out:
#          date  total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 0  2021-01-15                 0.0                0.0                      NaN
# 1  2021-01-16            191181.0           191181.0                      NaN
# 2  2021-01-17            224301.0           224301.0                      NaN
# 3  2021-01-18            454049.0           454049.0                      NaN
# 4  2021-01-19            674835.0           674835.0                      NaN
#
#    daily_vaccinations_raw  daily_vaccinations  total_vaccinations_per_hundred  \
# 0                     NaN                 NaN                            0.00
# 1                191181.0            191181.0                            0.01
# 2                 33120.0            112150.0                            0.02
# 3                229748.0            151350.0                            0.03
# 4                220786.0            168709.0                            0.05
#
#    people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                           0.00                                  NaN
# 1                           0.01                                  NaN
# 2                           0.02                                  NaN
# 3                           0.03                                  NaN
# 4                           0.05                                  NaN
#
#    daily_vaccinations_per_million
# 0                             NaN
# 1                           137.0
# 2                            80.0
# 3                           109.0
# 4                           121.0

# %%
df=data.fillna("0")
df
# Out:
#            date total_vaccinations people_vaccinated people_fully_vaccinated  \
# 0    2021-01-15                0.0               0.0                       0
# 1    2021-01-16           191181.0          191181.0                       0
# 2    2021-01-17           224301.0          224301.0                       0
# 3    2021-01-18           454049.0          454049.0                       0
# 4    2021-01-19           674835.0          674835.0                       0
# ..          ...                ...               ...                     ...
# 353  2022-01-03       1464526170.0       852570971.0             611955199.0
# 354  2022-01-04       1472330269.0       857788520.0             614541749.0
# 355  2022-01-05       1482203963.0       864466425.0             617737538.0
# 356  2022-01-06       1491991022.0       871088714.0             620902308.0
# 357  2022-01-07       1505591911.0       879625063.0             625966848.0
#
#     daily_vaccinations_raw daily_vaccinations total_vaccinations_per_hundred  \
# 0                        0                  0                            0.0
# 1                 191181.0           191181.0                           0.01
# 2                  33120.0           112150.0                           0.02
# 3                 229748.0           151350.0                           0.03
# 4                 220786.0           168709.0                           0.05
# ..                     ...                ...                            ...
# 353              7939936.0          6582722.0                          105.1
# 354              7804099.0          6608642.0                         105.66
# 355              9873694.0          6715446.0                         106.37
# 356              9787059.0          7610504.0                         107.07
# 357             13600889.0          8103784.0                         108.05
#
#     people_vaccinated_per_hundred people_fully_vaccinated_per_hundred  \
# 0                             0.0                                   0
# 1                            0.01                                   0
# 2                            0.02                                   0
# 3                            0.03                                   0
# 4                            0.05                                   0
# ..                            ...                                 ...
# 353                         61.19                               43.92
# 354                         61.56                                44.1
# 355                         62.04                               44.33
# 356                         62.51                               44.56
# 357                         63.13                               44.92
#
#     daily_vaccinations_per_million
# 0                                0
# 1                            137.0
# 2                             80.0
# 3                            109.0
# 4                            121.0
# ..                             ...
# 353                         4724.0
# 354                         4743.0
# 355                         4819.0
# 356                         5462.0
# 357                         5816.0
#
# [358 rows x 10 columns]

# %%
df['date'] = pd.to_datetime(df['date'], format = '%Y/%m/%d')
df.head().style.set_properties(subset=['date'], **{'background-color': 'dodgerblue'})
# Out:
# <style type="text/css">
# #T_0cf4d_row0_col0, #T_0cf4d_row1_col0, #T_0cf4d_row2_col0, #T_0cf4d_row3_col0, #T_0cf4d_row4_col0 {
#   background-color: dodgerblue;
# }
# </style>
# <table id="T_0cf4d_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >date</th>
#       <th class="col_heading level0 col1" >total_vaccinations</th>
#       <th class="col_heading level0 col2" >people_vaccinated</th>
#       <th class="col_heading level0 col3" >people_fully_vaccinated</th>
#       <th class="col_heading level0 col4" >daily_vaccinations_raw</th>
#       <th class="col_heading level0 col5" >daily_vaccinations</th>
#       <th class="col_heading level0 col6" >total_vaccinations_per_hundred</th>
#       <th class="col_heading level0 col7" >people_vaccinated_per_hundred</th>
#       <th class="col_heading level0 col8" >people_fully_vaccinated_per_hundred</th>
#       <th class="col_heading level0 col9" >daily_vaccinations_per_million</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cf4d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0cf4d_row0_col0" class="data row0 col0" >2021-01-15 00:00:00</td>
#       <td id="T_0cf4d_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_0cf4d_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_0cf4d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0cf4d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_0cf4d_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_0cf4d_row0_col6" class="data row0 col6" >0.000000</td>
#       <td id="T_0cf4d_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_0cf4d_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_0cf4d_row0_col9" class="data row0 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0cf4d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0cf4d_row1_col0" class="data row1 col0" >2021-01-16 00:00:00</td>
#       <td id="T_0cf4d_row1_col1" class="data row1 col1" >191181.000000</td>
#       <td id="T_0cf4d_row1_col2" class="data row1 col2" >191181.000000</td>
#       <td id="T_0cf4d_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_0cf4d_row1_col4" class="data row1 col4" >191181.000000</td>
#       <td id="T_0cf4d_row1_col5" class="data row1 col5" >191181.000000</td>
#       <td id="T_0cf4d_row1_col6" class="data row1 col6" >0.010000</td>
#       <td id="T_0cf4d_row1_col7" class="data row1 col7" >0.010000</td>
#       <td id="T_0cf4d_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_0cf4d_row1_col9" class="data row1 col9" >137.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0cf4d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0cf4d_row2_col0" class="data row2 col0" >2021-01-17 00:00:00</td>
#       <td id="T_0cf4d_row2_col1" class="data row2 col1" >224301.000000</td>
#       <td id="T_0cf4d_row2_col2" class="data row2 col2" >224301.000000</td>
#       <td id="T_0cf4d_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_0cf4d_row2_col4" class="data row2 col4" >33120.000000</td>
#       <td id="T_0cf4d_row2_col5" class="data row2 col5" >112150.000000</td>
#       <td id="T_0cf4d_row2_col6" class="data row2 col6" >0.020000</td>
#       <td id="T_0cf4d_row2_col7" class="data row2 col7" >0.020000</td>
#       <td id="T_0cf4d_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_0cf4d_row2_col9" class="data row2 col9" >80.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0cf4d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0cf4d_row3_col0" class="data row3 col0" >2021-01-18 00:00:00</td>
#       <td id="T_0cf4d_row3_col1" class="data row3 col1" >454049.000000</td>
#       <td id="T_0cf4d_row3_col2" class="data row3 col2" >454049.000000</td>
#       <td id="T_0cf4d_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_0cf4d_row3_col4" class="data row3 col4" >229748.000000</td>
#       <td id="T_0cf4d_row3_col5" class="data row3 col5" >151350.000000</td>
#       <td id="T_0cf4d_row3_col6" class="data row3 col6" >0.030000</td>
#       <td id="T_0cf4d_row3_col7" class="data row3 col7" >0.030000</td>
#       <td id="T_0cf4d_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_0cf4d_row3_col9" class="data row3 col9" >109.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0cf4d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0cf4d_row4_col0" class="data row4 col0" >2021-01-19 00:00:00</td>
#       <td id="T_0cf4d_row4_col1" class="data row4 col1" >674835.000000</td>
#       <td id="T_0cf4d_row4_col2" class="data row4 col2" >674835.000000</td>
#       <td id="T_0cf4d_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_0cf4d_row4_col4" class="data row4 col4" >220786.000000</td>
#       <td id="T_0cf4d_row4_col5" class="data row4 col5" >168709.000000</td>
#       <td id="T_0cf4d_row4_col6" class="data row4 col6" >0.050000</td>
#       <td id="T_0cf4d_row4_col7" class="data row4 col7" >0.050000</td>
#       <td id="T_0cf4d_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_0cf4d_row4_col9" class="data row4 col9" >121.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
from fbprophet import Prophet
ds=pd.DataFrame(columns=['ds','y'])

ds['ds']=df['date']
ds['y']=df['total_vaccinations']
model = Prophet(changepoint_range=1)
model.fit(ds)
future = model.make_future_dataframe(periods=20)
f=model.predict(future)
f['ds']=pd.to_datetime(f['ds'], format='%Y-%m-%d')
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
today=f[f['ds']=='2022-01-1 00:00:00']
with plt.xkcd():
    fig=plt.figure(figsize=(15,8))
    
        
    ax=sns.lineplot(data=f, x='ds',y='yhat', alpha=1, color='red')
    ax=sns.lineplot(data=df, x='date',y='total_vaccinations')
    
    
    ax.annotate(s=str(np.round(f['yhat'].iloc[-1],0))+ "\n"+ str(f['ds'].iloc[-1]), xy=(f['ds'].iloc[-1],f['yhat'].iloc[-1]))
    ax.annotate(s=str(np.round(today['yhat'].iloc[-1],0))+ "\n"+ str(today['ds'].iloc[-1]), xy=(today['ds'].iloc[-1],today['yhat'].iloc[-1]))
    
    ax.annotate(s="Total Vaccinations in India", xy=(0.70,0.25), xycoords='figure fraction', xytext=(0.60, 0.15),arrowprops={'arrowstyle':'-|>','color':'black'})
    
    ax.legend(labels=['Predicted','Actual'], loc='upper left')
